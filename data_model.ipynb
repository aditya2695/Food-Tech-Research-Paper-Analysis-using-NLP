# %%
import pandas as pd
import numpy as np
import re

# %%
journal_df = pd.read_csv('data/journals.csv')
journal_df.head(3)
# Out:
#                                              authors  \
# 0  Yu-Xiao Wang; Yue Xin; Jun-Yi Yin; Xiao-Jun Hu...
# 1  Yu-Xiao Wang; Yue Xin; Xiao-Jun Huang; Jun-Yi ...
# 2  Yu-Xiao Wang; Ting Zhang; Jun-Yi Yin; Xiao-Jun...
#
#                                                title  \
# 0  Revealing the architecture and solution proper...
# 1  A branched galactoglucan with flexible chains ...
# 2  Structural characterization and rheological pr...
#
#                                             abstract        journal_name
# 0  Macrolepiota albuminosa (Berk.) Pegler is abun...      Food Chemistry
# 1  A homogeneous galactoglucan was purified from ...      Food Chemistry
# 2  A homogeneous beta-glucan (JHMP-70) was obtain...  Food Hydrocolloids

# %% [markdown]
# ## Journal and Title dfs

# %%
# Extract unique journal names and assign unique IDs
journal_names = journal_df['journal_name'].unique()
journal_ids = range(len(journal_names))

# Create a DataFrame for journal mapping
journal_mapping_df = pd.DataFrame({
    'Journal': journal_names,
    'Journal_ID': journal_ids
})

# Assign unique IDs to titles and create a DataFrame for title mapping
title_ids = range(len(journal_df))
title_mapping_df = pd.DataFrame({
    'Title': journal_df['title'],
    'Title_ID': title_ids,
    'Journal_ID': journal_df['journal_name'].map(journal_mapping_df.set_index('Journal')['Journal_ID'])
})


journal_mapping_df.to_csv('data/data_model/journal_mapping.csv',index=False)
title_mapping_df.to_csv('data/data_model/title_mapping.csv',index=False)

# %%
title_mapping_df.head()
# Out:
#                                                Title  Title_ID  Journal_ID
# 0  Revealing the architecture and solution proper...         0           0
# 1  A branched galactoglucan with flexible chains ...         1           0
# 2  Structural characterization and rheological pr...         2           1
# 3  Dispersive micro-solid-phase extraction of aca...         3           2
# 4  The identification of biotransformation pathwa...         4           0

# %%
rows = []
for idx, row in enumerate(journal_df['authors']):
    authors = row.split('; ')
    title = journal_df['title'][idx]
    
    for author in authors:
        rows.append([author.strip(), title])


authors_df = pd.DataFrame(rows, columns=['author', 'title'])

# %%
authors_df.head(20)
# Out:
#             author                                              title
# 0     Yu-Xiao Wang  Revealing the architecture and solution proper...
# 1          Yue Xin  Revealing the architecture and solution proper...
# 2       Jun-Yi Yin  Revealing the architecture and solution proper...
# 3   Xiao-Jun Huang  Revealing the architecture and solution proper...
# 4    Jun-Qiao Wang  Revealing the architecture and solution proper...
# 5       Jie-Lun Hu  Revealing the architecture and solution proper...
# 6        Fang Geng  Revealing the architecture and solution proper...
# 7    Shao-Ping Nie  Revealing the architecture and solution proper...
# 8     Yu-Xiao Wang  A branched galactoglucan with flexible chains ...
# 9          Yue Xin  A branched galactoglucan with flexible chains ...
# 10  Xiao-Jun Huang  A branched galactoglucan with flexible chains ...
# 11      Jun-Yi Yin  A branched galactoglucan with flexible chains ...
# 12   Shao-Ping Nie  A branched galactoglucan with flexible chains ...
# 13    Yu-Xiao Wang  Structural characterization and rheological pr...
# 14      Ting Zhang  Structural characterization and rheological pr...
# 15      Jun-Yi Yin  Structural characterization and rheological pr...
# 16  Xiao-Jun Huang  Structural characterization and rheological pr...
# 17   Jun-Qiao Wang  Structural characterization and rheological pr...
# 18      Jie-Lun Hu  Structural characterization and rheological pr...
# 19   Shao-Ping Nie  Structural characterization and rheological pr...

# %%
# authors_df.to_csv('data/data_model/authors.csv',index=False)

# %%
repeating_authors = authors_df.groupby('author').size().reset_index(name='count')
repeating_authors = repeating_authors[repeating_authors['count'] > 1]
repeating_authors.sort_values(by='count',ascending=False)
# Out:
#                          author  count
# 14459               Petkova, M.     89
# 16181                  Sanz, Y.     89
# 10796                 Kouba, M.     89
# 15222                 Ramos, F.     89
# 2134               Bampidis, V.     89
# ...                         ...    ...
# 9233   Illathu Madhavamenon, K.      2
# 9235               Imaizumi, T.      2
# 9285                  Isoda, H.      2
# 9287              Issa-Issa, H.      2
# 22649                        a.      2
#
# [3756 rows x 2 columns]

# %% [markdown]
# ## **titles to NER mapping**

# %%
ner_df = pd.read_csv('data/data_model/ner_outputs.csv')
ner_df.head(3)
# Out:
#                                                Title  \
# 0  Revealing the architecture and solution proper...
# 1  A branched galactoglucan with flexible chains ...
# 2  Structural characterization and rheological pr...
#
#                                               Entity  \
# 0  Macrolepiota albuminosa (Berk.) Pegler,polysac...
# 1  galactoglucan,polysaccharides,Macrolepiota alb...
# 2  beta-glucan,JHMP-70,Hypsizygus marmoreus,ethan...
#
#                                          Entity_Type
# 0  MUSHROOM ,POLYSACCHARIDE,MUSHROOM ,CARBOHYDRAT...
# 1  POLYSACCHARIDE,POLYSACCHARIDE,MUSHROOM ,CHEMIC...
# 2  PROTEIN,MUSHROOM ,TOXIN,CHEMICAL,PROPERTY,APPL...

# %% [markdown]
# ## **Entity type frequency**

# %%
len(ner_df.iloc[0].Entity_Type.split(',')),len(ner_df.iloc[0].Entity.split(','))
# Out:
# (25, 25)

# %%
ent_types = pd.read_csv('data/data_model/entity_types.csv')
ent_type_list = list(ent_types['Entity Type'])

entity_type_freq_df = pd.DataFrame(columns=['Title'] + ent_type_list + ['total_ent_types'])

for index, row in ner_df.iterrows():
    present = row.Entity_Type.split(',')
    
    # Create a dictionary to store the frequency of each entity type
    frequency = {entity_type: 0 for entity_type in ent_type_list}
    
    # Count the frequency of each present entity type
    for entity_type in present:
        if entity_type in ent_type_list:
            frequency[entity_type] += 1
    
    # Compute the total count of entity types
    total_ent_types = sum(frequency.values())
    
    # Append a new row to the entity type DataFrame
    entity_type_freq_df.loc[len(entity_type_freq_df)] = [row.Title] + list(frequency.values()) + [total_ent_types]

entity_type_freq_df.head()
# Out:
#                                                Title  ORG  AGE GROUP  \
# 0  Revealing the architecture and solution proper...    1          0
# 1  A branched galactoglucan with flexible chains ...    1          0
# 2  Structural characterization and rheological pr...    1          0
# 3  Dispersive micro-solid-phase extraction of aca...    2          0
# 4  The identification of biotransformation pathwa...    1          0
#
#    PLANT SPECIES  CONDITION  DRINK  LOC  BACTERIUM  CARBOHYDRATES   \
# 0              0          0      0    0          0               2
# 1              0          0      0    1          0               0
# 2              0          0      0    0          0               1
# 3              1          0      2    0          0               0
# 4              0          1      0    0          0               0
#
#    OBSERVATION  ...  TECHNIQUE  MATERIAL  POLYSACCHARIDE  ANIMAL MODEL  \
# 0            0  ...          2         0               5             0
# 1            1  ...          2         0               3             0
# 2            0  ...          3         0               1             0
# 3            0  ...          5         2               0             0
# 4            0  ...          6         2               0             0
#
#    MUSHROOM   APPLICATION  CHEMICAL  BIOLOGICAL PATHWAY  MONOSACCHARIDE  \
# 0          7            0         0                   0               0
# 1          2            2         2                   0               2
# 2          2            4         2                   0               1
# 3          0            0        11                   0               0
# 4          0            0        11                   0               0
#
#    total_ent_types
# 0               25
# 1               23
# 2               30
# 3               38
# 4               32
#
# [5 rows x 32 columns]

# %% [markdown]
# ## **Entity Frequency**

# %%
entity_dict = {}

for entities, types in zip(ner_df['Entity'], ner_df['Entity_Type']):
    entities_list = entities.split(',')
    type_list = types.split(',')

    for i in range(len(entities_list)):
        if entities_list[i] not in entity_dict:
            entity_dict[entities_list[i]] = type_list[i]

# Create entity_df from entity_dict
entity_df = pd.DataFrame({'entity': list(entity_dict.keys()), 'entity_type': list(entity_dict.values())})
entity_df['entity_id'] = range(1, len(entity_df) + 1)
entity_df = entity_df[['entity_id', 'entity', 'entity_type']]
entity_df.head
# Out:
# 25 25
# 23 23
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 48 48
# 19 19
# 25 25
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 33 31
# Error processing entities and types: Lengths of entities and types do not match
# 39 39
# 11 11
# 46 46
# 33 33
# 38 38
# 50 50
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 35 35
# 8 8
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 9 9
# 13 13
# 23 23
# 26 26
# 13 13
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 20 20
# 27 27
# 23 23
# 50 49
# Error processing entities and types: Lengths of entities and types do not match
# 11 11
# 10 10
# 16 16
# 50 50
# 21 21
# 17 17
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 42 42
# 17 17
# 32 32
# 23 23
# 29 29
# 30 30
# 28 28
# 24 24
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 36 36
# 26 26
# 36 36
# 13 13
# 34 34
# 22 22
# 40 40
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 30 30
# 19 19
# 26 26
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 21 21
# 24 24
# 36 36
# 30 30
# 16 16
# 16 16
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 39 39
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 24 24
# 25 25
# 37 37
# 21 21
# 13 13
# 24 24
# 26 26
# 38 38
# 29 29
# 25 25
# 21 21
# 20 20
# 53 53
# 21 21
# 17 17
# 39 38
# Error processing entities and types: Lengths of entities and types do not match
# 37 35
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 13 13
# 29 29
# 27 27
# 19 19
# 11 11
# 18 18
# 18 18
# 17 17
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 25 25
# 28 28
# 25 25
# 26 26
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 25 25
# 11 11
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 16 16
# 27 27
# 33 30
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 63 63
# 28 28
# 19 19
# 28 28
# 30 30
# 28 28
# 40 40
# 32 32
# 15 15
# 38 38
# 20 20
# 15 15
# 22 22
# 13 11
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 28 28
# 27 27
# 17 17
# 44 43
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 12 12
# 20 20
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 21 21
# 33 33
# 20 20
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 15 15
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 35 35
# 32 32
# 22 22
# 31 31
# 39 39
# 36 34
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 25 25
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 27 27
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 55 55
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 35 35
# 29 29
# 22 22
# 19 19
# 18 18
# 33 33
# 38 38
# 24 24
# 41 41
# 24 24
# 26 26
# 33 31
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 50 50
# 32 32
# 25 25
# 16 16
# 22 22
# 34 34
# 19 19
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 17 17
# 24 24
# 17 17
# 17 17
# 32 32
# 26 26
# 40 40
# 16 16
# 26 26
# 50 49
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 15 15
# 25 25
# 38 38
# 16 16
# 14 14
# 44 42
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 20 20
# 28 28
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 18 18
# 19 19
# 25 23
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 66 66
# 38 38
# 15 15
# 31 31
# 19 19
# 25 25
# 35 35
# 19 19
# 11 11
# 13 13
# 29 29
# 34 34
# 52 52
# 18 18
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 31 31
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 35 35
# 41 41
# 13 13
# 39 38
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 28 28
# 44 44
# 28 28
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 18 18
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 24 24
# 14 14
# 28 28
# 30 30
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 27 25
# Error processing entities and types: Lengths of entities and types do not match
# 36 36
# 19 19
# 28 28
# 32 32
# 10 10
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 20 20
# 26 26
# 32 32
# 27 27
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 39 39
# 27 27
# 33 33
# 18 18
# 21 21
# 22 22
# 31 31
# 23 23
# 49 49
# 37 37
# 28 28
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 15 15
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 33 33
# 31 31
# 34 34
# 44 44
# 39 39
# 22 22
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 20 20
# 14 14
# 12 12
# 33 33
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 54 54
# 14 14
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 22 22
# 20 20
# 20 20
# 17 17
# 17 17
# 37 37
# 14 14
# 17 17
# 34 34
# 33 33
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 25 25
# 44 39
# Error processing entities and types: Lengths of entities and types do not match
# 32 30
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 39 39
# 13 13
# 16 16
# 42 42
# 30 30
# 14 14
# 47 46
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 34 34
# 45 44
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 23 23
# 32 32
# 34 34
# 52 51
# Error processing entities and types: Lengths of entities and types do not match
# 52 52
# 23 21
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 33 33
# 30 30
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 17 17
# 17 17
# 34 32
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 32 32
# 25 22
# Error processing entities and types: Lengths of entities and types do not match
# 30 28
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 31 31
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 61 60
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 23 23
# 23 23
# 33 33
# 37 37
# 43 43
# 27 27
# 36 36
# 45 44
# Error processing entities and types: Lengths of entities and types do not match
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 29 29
# 25 25
# 23 23
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 41 39
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 45 43
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 39 39
# 23 23
# 25 25
# 23 23
# 39 39
# 33 33
# 21 21
# 46 46
# 12 11
# Error processing entities and types: Lengths of entities and types do not match
# 44 44
# 14 14
# 16 16
# 25 25
# 19 19
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 26 26
# 24 24
# 25 25
# 26 26
# 39 39
# 23 23
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 27 27
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 22 22
# 41 41
# 28 28
# 28 28
# 34 34
# 24 24
# 18 18
# 25 25
# 39 35
# Error processing entities and types: Lengths of entities and types do not match
# 49 47
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 45 45
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 23 23
# 12 12
# 15 15
# 48 48
# 31 31
# 16 16
# 26 26
# 16 16
# 18 18
# 19 19
# 45 45
# 20 20
# 17 17
# 14 14
# 48 48
# 67 67
# 16 16
# 61 61
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 19 19
# 36 36
# 45 45
# 32 32
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 38 38
# 33 33
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 29 29
# 17 17
# 20 20
# 36 36
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 18 18
# 30 30
# 24 24
# 26 26
# 34 34
# 19 19
# 53 52
# Error processing entities and types: Lengths of entities and types do not match
# 22 20
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 36 36
# 32 32
# 27 27
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 27 27
# 39 39
# 19 19
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 26 26
# 29 29
# 39 39
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 49 49
# 18 18
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 25 25
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 25 25
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 19 19
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 40 40
# 28 28
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 42 42
# 28 28
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 33 33
# 37 37
# 17 17
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 30 30
# 16 16
# 31 31
# 19 19
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 35 35
# 17 17
# 13 13
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 42 42
# 14 14
# 29 29
# 25 25
# 32 32
# 36 36
# 20 20
# 31 31
# 27 27
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 43 43
# 23 23
# 16 16
# 21 21
# 49 49
# 24 24
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 33 31
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 17 17
# 10 10
# 20 20
# 14 14
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 18 18
# 11 11
# 20 20
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 42 42
# 18 18
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 30 30
# 36 36
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 47 47
# 21 21
# 19 19
# 36 36
# 22 22
# 35 35
# 37 37
# 43 43
# 33 31
# Error processing entities and types: Lengths of entities and types do not match
# 48 45
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 25 25
# 20 20
# 20 20
# 38 38
# 13 13
# 25 25
# 28 28
# 23 23
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 18 18
# 23 23
# 24 24
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 56 54
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 43 41
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 26 26
# 15 15
# 32 32
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 47 47
# 44 42
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 28 28
# 22 22
# 13 13
# 28 28
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 25 25
# 31 31
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 43 41
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 48 48
# 23 23
# 28 28
# 25 25
# 38 38
# 30 30
# 36 36
# 49 46
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 20 20
# 16 16
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 19 19
# 35 35
# 55 54
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 20 20
# 25 23
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 21 21
# 25 25
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 27 27
# 28 28
# 18 18
# 23 23
# 20 17
# Error processing entities and types: Lengths of entities and types do not match
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 13 13
# 23 23
# 26 26
# 29 29
# 12 12
# 14 14
# 20 20
# 24 24
# 25 25
# 31 29
# Error processing entities and types: Lengths of entities and types do not match
# 36 36
# 18 18
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 43 43
# 10 10
# 37 37
# 30 30
# 31 31
# 14 14
# 21 21
# 15 15
# 21 21
# 25 25
# 27 27
# 34 34
# 32 32
# 23 23
# 30 30
# 38 38
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 18 18
# 28 28
# 33 33
# 21 21
# 32 32
# 26 26
# 18 18
# 31 31
# 27 27
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 31 31
# 55 55
# 36 36
# 36 36
# 17 17
# 19 19
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 10 10
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 33 31
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 24 24
# 26 26
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 28 28
# 24 24
# 41 41
# 37 37
# 24 24
# 19 19
# 18 18
# 31 31
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 25 25
# 34 34
# 20 20
# 36 36
# 12 11
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 20 18
# Error processing entities and types: Lengths of entities and types do not match
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 36 36
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 74 73
# Error processing entities and types: Lengths of entities and types do not match
# 40 40
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 10 10
# 26 26
# 16 16
# 33 33
# 30 30
# 29 29
# 32 32
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 33 33
# 22 22
# 25 25
# 21 21
# 40 40
# 32 32
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 26 26
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 22 22
# 27 27
# 15 15
# 24 24
# 20 20
# 31 31
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 17 17
# 23 23
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 40 40
# 37 37
# 21 21
# 43 43
# 34 34
# 28 28
# 42 42
# 37 37
# 26 26
# 33 33
# 25 25
# 14 14
# 25 25
# 30 30
# 12 12
# 22 22
# 22 22
# 13 13
# 34 34
# 21 21
# 25 25
# 38 38
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 46 46
# 22 22
# 60 60
# 39 39
# 31 31
# 35 35
# 38 38
# 16 16
# 21 21
# 28 28
# 32 32
# 40 40
# 35 35
# 36 36
# 18 18
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 27 27
# 33 33
# 9 9
# 29 29
# 35 35
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 29 29
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 22 22
# 25 21
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 30 30
# 26 26
# 28 28
# 10 10
# 28 28
# 16 16
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 39 39
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 11 11
# 40 40
# 18 18
# 35 35
# 19 19
# 49 49
# 28 28
# 46 46
# 32 32
# 26 26
# 42 42
# 23 23
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 35 35
# 39 39
# 26 26
# 21 21
# 29 29
# 29 29
# 16 16
# 23 23
# 30 30
# 28 28
# 30 30
# 34 34
# 20 20
# 14 14
# 26 26
# 22 22
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 36 36
# 38 38
# 28 28
# 20 20
# 20 20
# 22 22
# 46 46
# 35 33
# Error processing entities and types: Lengths of entities and types do not match
# 2 2
# 25 25
# 28 28
# 25 25
# 62 62
# 23 23
# 23 23
# 58 58
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 24 24
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 28 28
# 23 23
# 35 35
# 41 41
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 11 11
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 24 24
# 39 39
# 30 30
# 17 17
# 33 33
# 53 53
# 40 40
# 21 19
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 27 27
# 48 47
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 24 24
# 35 35
# 49 49
# 21 21
# 29 26
# Error processing entities and types: Lengths of entities and types do not match
# 10 10
# 25 25
# 27 27
# 8 8
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 34 34
# 28 28
# 41 41
# 26 26
# 29 29
# 27 27
# 37 35
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 23 23
# 26 26
# 23 23
# 35 35
# 28 28
# 30 30
# 23 23
# 23 23
# 20 20
# 25 25
# 18 18
# 35 35
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 31 29
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 25 25
# 30 30
# 32 32
# 16 16
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 37 37
# 36 36
# 13 13
# 27 27
# 32 32
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 37 37
# 33 33
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 47 46
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 23 23
# 34 34
# 17 15
# Error processing entities and types: Lengths of entities and types do not match
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 23 23
# 17 17
# 33 33
# 15 15
# 28 28
# 31 31
# 35 35
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 20 20
# 40 40
# 37 37
# 29 29
# 29 29
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 19 19
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 40 38
# Error processing entities and types: Lengths of entities and types do not match
# 46 46
# 36 36
# 33 33
# 21 21
# 28 28
# 29 29
# 21 21
# 46 46
# 25 25
# 28 28
# 34 34
# 25 25
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 21 21
# 11 11
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 25 25
# 27 27
# 44 44
# 22 22
# 48 48
# 39 39
# 20 20
# 33 33
# 30 27
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 20 20
# 47 46
# Error processing entities and types: Lengths of entities and types do not match
# 40 40
# 34 34
# 21 21
# 23 23
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 54 54
# 18 18
# 47 47
# 27 27
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 36 34
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 14 14
# 27 27
# 41 41
# 25 25
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 31 31
# 30 30
# 20 20
# 24 24
# 39 39
# 47 47
# 35 35
# 38 38
# 24 24
# 23 23
# 28 28
# 40 40
# 25 25
# 20 20
# 24 24
# 29 29
# 28 28
# 36 36
# 21 21
# 24 24
# 30 30
# 23 23
# 17 17
# 30 30
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 48 48
# 48 47
# Error processing entities and types: Lengths of entities and types do not match
# 51 50
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 25 25
# 19 19
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 26 26
# 14 14
# 28 28
# 36 36
# 27 27
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 26 26
# 44 44
# 45 45
# 21 21
# 14 14
# 27 27
# 38 38
# 41 41
# 32 30
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 14 13
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 31 31
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 33 33
# 26 26
# 31 31
# 20 20
# 22 22
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 42 42
# 17 17
# 20 20
# 20 20
# 24 24
# 27 27
# 25 25
# 29 29
# 25 25
# 23 23
# 32 32
# 33 33
# 13 13
# 34 34
# 21 21
# 34 34
# 21 21
# 31 31
# 29 29
# 34 34
# 23 23
# 19 19
# 25 25
# 32 32
# 23 23
# 26 26
# 26 26
# 24 24
# 27 27
# 26 26
# 30 30
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 13 13
# 24 24
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 33 33
# 20 20
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 54 54
# 24 24
# 17 17
# 16 16
# 28 28
# 32 32
# 29 29
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 21 21
# 36 36
# 23 21
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 34 34
# 25 25
# 20 20
# 48 47
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 52 52
# 18 18
# 26 23
# Error processing entities and types: Lengths of entities and types do not match
# 11 11
# 27 27
# 21 21
# 43 43
# 20 20
# 35 35
# 35 35
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 31 29
# Error processing entities and types: Lengths of entities and types do not match
# 26 24
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 38 38
# 15 15
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 51 51
# 30 30
# 11 11
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 43 43
# 27 27
# 28 28
# 20 20
# 15 15
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 27 27
# 39 39
# 25 25
# 43 43
# 40 38
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 33 33
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 39 39
# 21 21
# 57 56
# Error processing entities and types: Lengths of entities and types do not match
# 45 44
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 34 31
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 19 19
# 13 12
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 13 13
# 24 24
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 8 7
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 63 62
# Error processing entities and types: Lengths of entities and types do not match
# 70 70
# 16 16
# 18 18
# 19 19
# 30 26
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 22 22
# 44 43
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 13 13
# 13 13
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 6 6
# 15 15
# 39 39
# 28 28
# 26 26
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 17 17
# 27 27
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 42 42
# 37 37
# 42 42
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 10 10
# 11 11
# 29 29
# 5 5
# 26 26
# 43 43
# 20 20
# 28 28
# 30 30
# 18 18
# 39 37
# Error processing entities and types: Lengths of entities and types do not match
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 26 26
# 24 24
# 19 19
# 39 36
# Error processing entities and types: Lengths of entities and types do not match
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 50 50
# 25 25
# 34 34
# 48 48
# 16 16
# 42 42
# 85 83
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 24 24
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 10 8
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 32 32
# 24 24
# 24 24
# 33 31
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 17 17
# 25 25
# 31 31
# 22 22
# 41 41
# 37 37
# 34 34
# 37 37
# 5 5
# 35 35
# 20 20
# 22 22
# 27 27
# 20 20
# 23 23
# 15 15
# 16 16
# 23 23
# 37 37
# 48 48
# 33 33
# 20 20
# 24 24
# 20 20
# 14 14
# 30 30
# 14 14
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 51 50
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 11 11
# 26 26
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 45 44
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 29 29
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 22 18
# Error processing entities and types: Lengths of entities and types do not match
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 13 12
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 40 40
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 12 11
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 31 31
# 60 59
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 44 44
# 30 30
# 21 21
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 27 27
# 28 28
# 33 33
# 38 38
# 34 34
# 37 37
# 38 38
# 24 24
# 41 41
# 21 21
# 36 36
# 40 40
# 15 15
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 24 24
# 12 12
# 11 11
# 33 33
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 9 8
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 12 11
# Error processing entities and types: Lengths of entities and types do not match
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 27 27
# 30 30
# 37 35
# Error processing entities and types: Lengths of entities and types do not match
# 27 25
# Error processing entities and types: Lengths of entities and types do not match
# 39 38
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 9 9
# 24 24
# 34 34
# 40 40
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 45 42
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 32 32
# 21 21
# 28 28
# 33 33
# 21 21
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 19 19
# 46 46
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 24 24
# 23 23
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 42 42
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 23 23
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 16 16
# 24 24
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 31 29
# Error processing entities and types: Lengths of entities and types do not match
# 13 12
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 26 26
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 17 17
# 37 37
# 36 36
# 29 29
# 53 53
# 26 26
# 30 30
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 20 20
# 20 20
# 17 17
# 22 22
# 25 25
# 40 38
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 32 32
# 21 21
# 20 20
# 36 36
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 16 16
# 29 29
# 34 34
# 47 47
# 25 25
# 30 30
# 25 25
# 27 27
# 16 16
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 66 66
# 43 41
# Error processing entities and types: Lengths of entities and types do not match
# 54 53
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 12 12
# 33 33
# 21 21
# 22 22
# 31 31
# 12 12
# 77 77
# 37 35
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 18 18
# 33 33
# 14 13
# Error processing entities and types: Lengths of entities and types do not match
# 12 12
# 35 35
# 18 18
# 58 58
# 25 25
# 23 23
# 23 23
# 32 30
# Error processing entities and types: Lengths of entities and types do not match
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 24 24
# 20 20
# 26 24
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 25 25
# 29 29
# 23 23
# 31 31
# 24 24
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 33 33
# 15 15
# 22 22
# 22 22
# 36 36
# 35 35
# 8 8
# 33 33
# 44 43
# Error processing entities and types: Lengths of entities and types do not match
# 40 40
# 11 11
# 41 41
# 15 15
# 26 23
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 20 20
# 17 17
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 16 16
# 27 27
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 24 24
# 21 21
# 20 20
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 39 39
# 15 15
# 13 13
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 11 11
# 29 29
# 26 26
# 26 26
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 45 43
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 26 26
# 27 27
# 31 31
# 19 19
# 21 21
# 33 33
# 24 24
# 46 46
# 37 37
# 26 26
# 17 17
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 51 50
# Error processing entities and types: Lengths of entities and types do not match
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 21 21
# 16 16
# 26 26
# 33 33
# 67 65
# Error processing entities and types: Lengths of entities and types do not match
# 45 44
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 19 19
# 26 24
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 16 16
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 38 38
# 28 28
# 27 27
# 17 17
# 34 34
# 45 45
# 20 20
# 24 24
# 43 43
# 20 20
# 23 23
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 8 8
# 20 20
# 39 37
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 22 22
# 30 30
# 28 26
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 14 14
# 51 51
# 50 50
# 19 19
# 37 37
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 47 47
# 30 30
# 23 23
# 22 22
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 21 21
# 38 38
# 31 31
# 17 17
# 16 16
# 35 35
# 18 18
# 17 17
# 29 29
# 25 25
# 17 17
# 57 57
# 36 36
# 54 54
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 40 40
# 30 30
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 45 45
# 23 23
# 17 17
# 14 14
# 33 33
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 23 23
# 19 19
# 27 27
# 19 19
# 22 22
# 24 24
# 19 19
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 49 49
# 13 12
# Error processing entities and types: Lengths of entities and types do not match
# 9 9
# 15 15
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 29 29
# 54 41
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 47 47
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 33 33
# 25 23
# Error processing entities and types: Lengths of entities and types do not match
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 17 17
# 27 27
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 57 56
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 29 26
# Error processing entities and types: Lengths of entities and types do not match
# 31 29
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 44 44
# 22 22
# 8 8
# 12 12
# 11 11
# 15 15
# 32 32
# 33 33
# 28 28
# 26 26
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 31 29
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 35 35
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 32 32
# 16 16
# 15 15
# 17 17
# 31 31
# 41 41
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 28 28
# 28 28
# 30 26
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 12 12
# 39 39
# 24 24
# 36 36
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 27 27
# 19 19
# 13 13
# 27 27
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 43 43
# 23 23
# 34 34
# 30 30
# 46 46
# 10 10
# 20 20
# 29 29
# 41 40
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 29 29
# 33 33
# 9 9
# 27 27
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 38 38
# 57 56
# Error processing entities and types: Lengths of entities and types do not match
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 37 37
# 36 36
# 23 23
# 24 24
# 26 26
# 23 23
# 27 27
# 23 23
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 33 30
# Error processing entities and types: Lengths of entities and types do not match
# 23 21
# Error processing entities and types: Lengths of entities and types do not match
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 42 41
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 47 47
# 45 45
# 5 5
# 18 18
# 42 42
# 40 36
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 27 27
# 27 27
# 38 38
# 21 21
# 30 30
# 27 27
# 8 8
# 11 11
# 30 30
# 11 11
# 16 16
# 31 31
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 11 11
# 31 31
# 17 17
# 24 24
# 32 32
# 32 32
# 21 21
# 32 32
# 26 26
# 31 31
# 12 12
# 22 22
# 14 14
# 15 15
# 36 34
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 60 59
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 20 17
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 33 33
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 17 17
# 19 17
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 21 21
# 14 13
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 20 20
# 12 12
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 33 33
# 36 36
# 24 24
# 20 20
# 21 21
# 17 17
# 37 37
# 22 22
# 20 20
# 19 19
# 19 19
# 12 11
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 23 23
# 25 23
# Error processing entities and types: Lengths of entities and types do not match
# 46 46
# 25 25
# 30 27
# Error processing entities and types: Lengths of entities and types do not match
# 29 27
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 18 18
# 24 24
# 36 36
# 24 24
# 23 23
# 27 27
# 28 28
# 31 31
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 40 38
# Error processing entities and types: Lengths of entities and types do not match
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 18 18
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 19 19
# 25 25
# 23 23
# 20 20
# 31 31
# 34 34
# 23 23
# 21 21
# 44 44
# 11 11
# 18 18
# 22 22
# 23 21
# Error processing entities and types: Lengths of entities and types do not match
# 52 51
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 27 27
# 27 27
# 12 12
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 33 33
# 39 39
# 24 24
# 20 20
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 44 44
# 31 31
# 37 37
# 20 20
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 29 29
# 26 26
# 23 23
# 37 37
# 41 41
# 21 21
# 24 24
# 29 29
# 29 29
# 31 31
# 12 12
# 32 32
# 22 22
# 24 24
# 12 12
# 11 11
# 22 22
# 13 13
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 16 16
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 25 25
# 20 20
# 20 20
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 37 37
# 40 40
# 21 21
# 11 11
# 30 30
# 21 21
# 46 46
# 37 37
# 25 25
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 50 49
# ...
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 29 29
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 36 36
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 30 30
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 22 22
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 40 40
# 13 13
# 24 24
# 25 25
# 20 20
# 23 23
# 22 22
# 25 25
# 16 16
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 36 36
# 44 44
# 40 40
# 29 29
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 24 24
# 28 28
# 32 32
# 22 22
# 22 22
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 23 23
# 27 27
# 26 26
# 22 22
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 40 40
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 9 9
# 43 43
# 20 20
# 24 24
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 29 29
# 12 12
# 26 26
# 36 36
# 36 36
# 25 25
# 19 19
# 22 22
# 26 26
# 43 41
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 34 34
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 18 16
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 22 22
# 27 27
# 9 9
# 24 24
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 32 29
# Error processing entities and types: Lengths of entities and types do not match
# 49 47
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 22 22
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 30 28
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 38 38
# 40 40
# 25 25
# 19 19
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 23 23
# 34 34
# 28 28
# 22 22
# 33 33
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 25 25
# 15 15
# 18 18
# 44 44
# 22 22
# 36 36
# 19 19
# 20 20
# 44 44
# 37 37
# 22 22
# 48 48
# 43 43
# 33 33
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 28 28
# 20 20
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 14 14
# 23 23
# 22 22
# 30 30
# 18 18
# 26 26
# 23 23
# 39 39
# 29 29
# 18 18
# 20 20
# 35 35
# 51 49
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 26 26
# 26 26
# 24 24
# 18 18
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 22 22
# 21 21
# 10 10
# 31 31
# 16 16
# 15 15
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 35 35
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 42 42
# 53 52
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 33 33
# 56 56
# 31 31
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 22 22
# 35 35
# 11 11
# 32 32
# 48 48
# 25 25
# 32 32
# 27 27
# 11 11
# 24 24
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 54 53
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 12 12
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 15 15
# 20 20
# 23 23
# 26 26
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 23 23
# 34 34
# 64 63
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 25 25
# 36 36
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 35 35
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 17 17
# 18 18
# 21 21
# 15 15
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 22 22
# 11 11
# 32 32
# 23 23
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 27 27
# 34 34
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 26 26
# 52 51
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 22 22
# 40 40
# 46 45
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 20 20
# 29 29
# 14 13
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 33 33
# 11 11
# 12 12
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 31 31
# 16 16
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 68 68
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 14 13
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 19 19
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 30 28
# Error processing entities and types: Lengths of entities and types do not match
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 30 27
# Error processing entities and types: Lengths of entities and types do not match
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 15 15
# 28 28
# 10 9
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 37 37
# 23 23
# 20 18
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 42 42
# 23 23
# 21 21
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 19 19
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 42 40
# Error processing entities and types: Lengths of entities and types do not match
# 37 37
# 17 17
# 24 24
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 12 11
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 28 27
# Error processing entities and types: Lengths of entities and types do not match
# 10 10
# 16 16
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 20 18
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 9 9
# 24 24
# 28 28
# 11 11
# 27 27
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 13 13
# 32 30
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 30 28
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 12 12
# 29 29
# 39 39
# 20 20
# 13 13
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 31 31
# 35 35
# 27 27
# 22 22
# 21 21
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 48 48
# 25 25
# 31 31
# 43 42
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 22 21
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 25 25
# 22 22
# 50 48
# Error processing entities and types: Lengths of entities and types do not match
# 46 46
# 24 24
# 19 19
# 23 23
# 28 28
# 30 30
# 25 25
# 13 13
# 29 29
# 13 13
# 19 19
# 39 38
# Error processing entities and types: Lengths of entities and types do not match
# 30 30
# 32 32
# 15 15
# 25 25
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 26 26
# 27 27
# 10 10
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 20 20
# 29 29
# 65 65
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 6 6
# 28 28
# 35 35
# 66 66
# 20 20
# 24 24
# 21 21
# 16 16
# 43 43
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 24 24
# 14 14
# 16 16
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 41 41
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 25 25
# 19 19
# 14 14
# 27 27
# 25 25
# 21 21
# 20 20
# 32 32
# 23 21
# Error processing entities and types: Lengths of entities and types do not match
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 22 20
# Error processing entities and types: Lengths of entities and types do not match
# 25 24
# Error processing entities and types: Lengths of entities and types do not match
# 38 37
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 42 42
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 18 18
# 23 23
# 36 36
# 16 16
# 27 27
# 24 24
# 15 15
# 28 28
# 20 20
# 30 30
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 53 53
# 19 19
# 21 21
# 14 14
# 13 13
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 23 23
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 31 30
# Error processing entities and types: Lengths of entities and types do not match
# 18 18
# 30 30
# 35 35
# 10 10
# 23 21
# Error processing entities and types: Lengths of entities and types do not match
# 21 21
# 24 24
# 13 13
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 17 17
# 13 13
# 6 6
# 42 42
# 27 27
# 23 23
# 10 10
# 16 16
# 29 29
# 26 26
# 37 37
# 35 34
# Error processing entities and types: Lengths of entities and types do not match
# 28 28
# 29 29
# 23 23
# 18 18
# 20 20
# 7 7
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 16 16
# 30 29
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 37 35
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 37 37
# 18 18
# 43 43
# 24 24
# 23 20
# Error processing entities and types: Lengths of entities and types do not match
# 9 9
# 24 24
# 40 40
# 38 38
# 25 25
# 13 13
# 19 19
# 26 26
# 45 45
# 55 54
# Error processing entities and types: Lengths of entities and types do not match
# 7 7
# 33 32
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 22 22
# 37 37
# 24 24
# 29 29
# 41 41
# 37 37
# 18 18
# 13 13
# 7 7
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 14 14
# 16 15
# Error processing entities and types: Lengths of entities and types do not match
# 15 14
# Error processing entities and types: Lengths of entities and types do not match
# 38 38
# 62 61
# Error processing entities and types: Lengths of entities and types do not match
# 29 28
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 28 28
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 48 48
# 29 29
# 23 23
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 42 42
# 33 33
# 57 57
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 44 44
# 33 33
# 37 37
# 21 21
# 33 33
# 28 28
# 36 36
# 34 34
# 33 33
# 20 19
# Error processing entities and types: Lengths of entities and types do not match
# 12 12
# 22 22
# 38 38
# 34 34
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 12 12
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 32 31
# Error processing entities and types: Lengths of entities and types do not match
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 28 26
# Error processing entities and types: Lengths of entities and types do not match
# 31 31
# 22 22
# 19 19
# 19 18
# Error processing entities and types: Lengths of entities and types do not match
# 6 6
# 12 12
# 44 44
# 39 38
# Error processing entities and types: Lengths of entities and types do not match
# 27 27
# 25 25
# 25 25
# 14 14
# 14 14
# 20 20
# 21 21
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 21 20
# Error processing entities and types: Lengths of entities and types do not match
# 20 20
# 17 17
# 24 24
# 18 17
# Error processing entities and types: Lengths of entities and types do not match
# 10 9
# Error processing entities and types: Lengths of entities and types do not match
# 34 34
# 50 48
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 37 36
# Error processing entities and types: Lengths of entities and types do not match
# 24 23
# Error processing entities and types: Lengths of entities and types do not match
# 17 17
# 49 49
# 43 43
# 25 25
# 37 37
# 24 24
# 30 30
# 21 21
# 32 30
# Error processing entities and types: Lengths of entities and types do not match
# 29 25
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 35 35
# 46 46
# 23 23
# 17 17
# 34 34
# 14 14
# 22 22
# 30 30
# 22 20
# Error processing entities and types: Lengths of entities and types do not match
# 10 10
# 28 28
# 21 21
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 17 16
# Error processing entities and types: Lengths of entities and types do not match
# 13 13
# 10 10
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 23 23
# 12 12
# 45 45
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 26 26
# 36 35
# Error processing entities and types: Lengths of entities and types do not match
# 46 46
# 24 24
# 24 24
# 51 51
# 20 20
# 40 40
# 42 42
# 40 39
# Error processing entities and types: Lengths of entities and types do not match
# 22 22
# 34 33
# Error processing entities and types: Lengths of entities and types do not match
# 23 22
# Error processing entities and types: Lengths of entities and types do not match
# 32 30
# Error processing entities and types: Lengths of entities and types do not match
# 21 19
# Error processing entities and types: Lengths of entities and types do not match
# 32 32
# 11 11
# 19 19
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 27 26
# Error processing entities and types: Lengths of entities and types do not match
# 10 10
# 26 25
# Error processing entities and types: Lengths of entities and types do not match
# 24 24
# 47 46
# Error processing entities and types: Lengths of entities and types do not match
# 36 36
# 35 35
# 25 25

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\DS_AI\Digital Futures\Projects\extras\portsmouth\data_model.ipynb Cell 17 in <cell line: 3>()
#      <a href='vscode-notebook-cell:/d%3A/DS_AI/Digital%20Futures/Projects/extras/portsmouth/data_model.ipynb#X32sZmlsZQ%3D%3D?line=14'>15</a>     total_entities = sum(frequency.values())
#      <a href='vscode-notebook-cell:/d%3A/DS_AI/Digital%20Futures/Projects/extras/portsmouth/data_model.ipynb#X32sZmlsZQ%3D%3D?line=16'>17</a>     # Append a new row to the entity type DataFrame
# ---> <a href='vscode-notebook-cell:/d%3A/DS_AI/Digital%20Futures/Projects/extras/portsmouth/data_model.ipynb#X32sZmlsZQ%3D%3D?line=17'>18</a>     entity_freq_df.loc[len(entity_freq_df)] = [row.Title] + list(frequency.values()) + [total_entities]
#      <a href='vscode-notebook-cell:/d%3A/DS_AI/Digital%20Futures/Projects/extras/portsmouth/data_model.ipynb#X32sZmlsZQ%3D%3D?line=19'>20</a> entity_freq_df.head()
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\indexing.py:1682, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1679     indexer, missing = convert_missing_indexer(indexer)
#    1681     if missing:
# -> 1682         self._setitem_with_indexer_missing(indexer, value)
#    1683         return
#    1685 # align and set the values
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\indexing.py:2020, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2018     self.obj._mgr = df._mgr
#    2019 else:
# -> 2020     self.obj._mgr = self.obj._append(value)._mgr
#    2021 self.obj._maybe_update_cacher(clear=True)
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\frame.py:9072, in DataFrame._append(self, other, ignore_index, verify_integrity, sort)
#    9069     row_df = other.to_frame().T
#    9070     # infer_objects is needed for
#    9071     #  test_append_empty_frame_to_series_with_dateutil_tz
# -> 9072     other = row_df.infer_objects().rename_axis(index.names, copy=False)
#    9073 elif isinstance(other, list):
#    9074     if not other:
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\util\_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\generic.py:1313, in NDFrame.rename_axis(self, mapper, **kwargs)
#    1309 non_mapper = is_scalar(mapper) or (
#    1310     is_list_like(mapper) and not is_dict_like(mapper)
#    1311 )
#    1312 if non_mapper:
# -> 1313     return self._set_axis_name(mapper, axis=axis, inplace=inplace)
#    1314 else:
#    1315     raise ValueError("Use `.rename` to alter labels with a mapper.")
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\generic.py:1391, in NDFrame._set_axis_name(self, name, axis, inplace)
#    1388 idx = self._get_axis(axis).set_names(name)
#    1390 inplace = validate_bool_kwarg(inplace, "inplace")
# -> 1391 renamed = self if inplace else self.copy()
#    1392 renamed.set_axis(idx, axis=axis, inplace=True)
#    1393 if not inplace:
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\generic.py:6032, in NDFrame.copy(self, deep)
#    5926 @final
#    5927 def copy(self: NDFrameT, deep: bool_t = True) -> NDFrameT:
#    5928     """
#    5929     Make a copy of this object's indices and data.
#    5930
#    (...)
#    6030     dtype: object
#    6031     """
# -> 6032     data = self._mgr.copy(deep=deep)
#    6033     self._clear_item_cache()
#    6034     return self._constructor(data).__finalize__(self, method="copy")
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\internals\managers.py:615, in BaseBlockManager.copy(self, deep)
#     612         res._blklocs = self._blklocs.copy()
#     614 if deep:
# --> 615     res._consolidate_inplace()
#     616 return res
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\internals\managers.py:1684, in BlockManager._consolidate_inplace(self)
#    1683 def _consolidate_inplace(self) -> None:
# -> 1684     if not self.is_consolidated():
#    1685         self.blocks = tuple(_consolidate(self.blocks))
#    1686         self._is_consolidated = True
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\internals\managers.py:1670, in BlockManager.is_consolidated(self)
#    1666 """
#    1667 Return True if more than one block with the same dtype
#    1668 """
#    1669 if not self._known_consolidated:
# -> 1670     self._consolidate_check()
#    1671 return self._is_consolidated
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\internals\managers.py:1679, in BlockManager._consolidate_check(self)
#    1677     self._known_consolidated = True
#    1678     return
# -> 1679 dtypes = [blk.dtype for blk in self.blocks if blk._can_consolidate]
#    1680 self._is_consolidated = len(dtypes) == len(set(dtypes))
#    1681 self._known_consolidated = True
#
# File c:\Users\adity\.conda\envs\env_pytorch\lib\site-packages\pandas\core\internals\managers.py:1679, in <listcomp>(.0)
#    1677     self._known_consolidated = True
#    1678     return
# -> 1679 dtypes = [blk.dtype for blk in self.blocks if blk._can_consolidate]
#    1680 self._is_consolidated = len(dtypes) == len(set(dtypes))
#    1681 self._known_consolidated = True
#
# KeyboardInterrupt:

# %%
entity_type_freq_df.to_csv('data/data_model/entity_type_frequency.csv',index=False)
